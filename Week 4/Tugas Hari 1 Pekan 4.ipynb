# %% [markdown]
# <h1>Soal 1: Pemahaman Machine Learning</h1>
#
# Jawab/Kerjakan pertanyaan/perintah di bawah ini dengan bahasa kalian sendiri:
#
# - Apa itu machine learning?
# - Apa itu data feature dan data target?
# - Apa Perbedaan Supervised Learning dan Unsupervised Learning?
# - Apa Jenis2 yang ada di dalam Supervised Learning? Jelaskan Perbedaannya!
# - Apa perbedaan Hyperparameter dan Parameter?
# - Sebutkan Langkah-langkah dalam mengaplikasikan algoritma apapun dalam machine learning!

# %% [markdown]
# ---

# %% [markdown]
# Jawaban:
# - Machine learning adalah suatu metode dimana komputer bisa belajar dari data yang telah dipelajari sebelumnya
# - Data feature adalah variabel independent atau merupakan predictor dari suatu dataset, data target adalah variabel dependent atau label dari suatu data
# - Supervised learning merupakan metode di ML dimana terdapat label/data target dalam prose belajar komputer, sedangkan pada Unsupervised learning tidak ada label/data target
# - Klasifikasi dan regresi. Pada klasifikasi data akan di kelompokan berdasarkan kategori tertentu sedangkan regresi data akan diprediksi secara continue
# - Hyperparameter didefinisikan di awal dan tidak berhubungan dengan model, sedangkan parameter didapatkan di akhir training dan berhubungan dengan model
# - Langkah-langkah aplikasi algoritma di ML:
#     1. Tentukan model algoritma yang akan digunakan
#     2. Tentukan hyperparameter untuk model tersebut
#     3. Split data menjadi feature dan label
#     4. Lakukan pelatihan model
#     5. Jalankan prediksi/regresi terhadap data baru
#     6. Evaluasi model tersebut

# %% [markdown]
# <h1>Soal 2: Pemahaman Machine Learning</h1>
#
# Pelajarilah secara garis besar suatu model/algoritma machine learning, kemudian aplikasikan untuk membuat model bagi data (variable x, y) di bawah ini. Kemudian buatlah prediksi terhadap data training dan data baru di interval 20-30.
#
# - Plot data asli, data hasil prediksi terhadap data training, data hasil prediksi terhadap data baru
# - Tunjukan beberapa parameter yang dimiliki model yang telah kalian buat

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.RandomState(42)
x = 20 * rng.rand(50)
y = x**2 + 2 * x + - 1 + rng.randn(50)

# data yang akan di prediksi
x_new = np.arange(20, 30, 0.5)

fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y)
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.show()

# %% [markdown]
# Contoh jawaban hasil pembuatan model dengan algoritma DecisionTreeRegressor (jawaban tidak harus sama):
#
# ![alt text](https://drive.google.com/uc?id=1R0mGnMp3DqEsHDiH2_IL4XSS2Roew0wo)

# %% [markdown]
# Contoh jawaban parameters (tidak harus sama):
#
# - Feature Importance : array([1.])
# - n features : 1
#
# Tree Graph :
#
# ![alt text](https://drive.google.com/uc?id=1GM0ba_qjm_e5oLhE9v6pVt2uRBBW6FH9)

# %%
# Code here
# 1. pilih model algoritma
from sklearn.ensemble import RandomForestRegressor

# 2. tentukan hyperparameters
regressor = RandomForestRegressor(n_estimators=15, random_state=0)

X_train = x[:, np.newaxis]
y_train = y[:, np.newaxis]
X_test = x_new[:, np.newaxis]

# 3. lakukan pembelajaran/training
regressor.fit(X_train, y_train)

# 4. lakukan prediksi dari model
y_pred = regressor.predict(X_test)
y_train_pred = regressor.predict(X_train)
# Out:
# /Users/ariflaksito/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]

# %%
y_pred
# Out:
# array([409.80100302, 409.80100302, 409.80100302, 409.80100302,
#        409.80100302, 409.80100302, 409.80100302, 409.80100302,
#        409.80100302, 409.80100302, 409.80100302, 409.80100302,
#        409.80100302, 409.80100302, 409.80100302, 409.80100302,
#        409.80100302, 409.80100302, 409.80100302, 409.80100302])

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y, label='Data asli')
ax.scatter(x, y_train_pred, label='Prediksi data training')
ax.plot(x_new, y_pred, label='Prediksi data baru')
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.legend()
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree

regr_1 = DecisionTreeRegressor(max_depth=6, min_samples_leaf= 0.1)
regr_1.fit(X_train, y_train)
y_pred = regr_1.predict(X_test)
y_train_pred = regr_1.predict(X_train)

# %%
y_pred
# Out:
# array([386.58502854, 386.58502854, 386.58502854, 386.58502854,
#        386.58502854, 386.58502854, 386.58502854, 386.58502854,
#        386.58502854, 386.58502854, 386.58502854, 386.58502854,
#        386.58502854, 386.58502854, 386.58502854, 386.58502854,
#        386.58502854, 386.58502854, 386.58502854, 386.58502854])

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y, label='Data asli')
ax.scatter(x, y_train_pred, label='Prediksi data training')
ax.plot(x_new, y_pred, label='Prediksi data baru')
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
tree.plot_tree(regr_1,fontsize=9) 
plt.show()
